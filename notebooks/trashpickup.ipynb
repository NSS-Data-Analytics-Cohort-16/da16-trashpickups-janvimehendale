# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read csv
trash_df_read = pd.read_csv('../data/trash_hauler_report_with_lat_lng.csv')
trash_df_read.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20226 entries, 0 to 20225
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    20226 non-null  int64
#  1   Date Opened       20226 non-null  object
#  2   Request           20226 non-null  object
#  3   Description       20195 non-null  object
#  4   Incident Address  20217 non-null  object
#  5   Zip Code          20151 non-null  float64
#  6   Trash Hauler      19325 non-null  object
#  7   Trash Route       19279 non-null  object
#  8   Council District  20177 non-null  float64
#  9   State Plan X      20198 non-null  float64
#  10  State Plan Y      20198 non-null  float64
#  11  LONGITUDE         20198 non-null  float64
#  12  LATITUDE          20198 non-null  float64
# dtypes: float64(6), int64(1), object(6)
# memory usage: 2.0+ MB

# %%
trash_df_read.head()
# Out:
#    Request Number Date Opened                               Request  \
# 0           25270   11/1/2017                      Trash - Backdoor
# 1           25274   11/1/2017  Trash - Curbside/Alley Missed Pickup
# 2           25276   11/1/2017  Trash - Curbside/Alley Missed Pickup
# 3           25307   11/1/2017  Trash - Curbside/Alley Missed Pickup
# 4           25312   11/1/2017  Trash - Curbside/Alley Missed Pickup
#
#                                          Description       Incident Address  \
# 0  house with the wheel chair ramp, they share dr...         3817 Crouch Dr
# 1                           Curb/Trash miss Tuesday.  4028 Clarksville Pike
# 2                           Curb/trash miss Tuesday.    6528 Thunderbird Dr
# 3                                             missed   2603 old matthews rd
# 4                  Missed the even side of the road.          604 croley dr
#
#    Zip Code Trash Hauler Trash Route  Council District  State Plan X  \
# 0   37207.0    RED RIVER        3205               2.0   1727970.412
# 1   37218.0    RED RIVER        4202               1.0   1721259.366
# 2   37209.0    RED RIVER        4205              20.0   1707026.753
# 3   37207.0    WASTE IND        2206               2.0   1735691.771
# 4   37209.0    RED RIVER        4203              20.0   1710185.772
#
#    State Plan Y  LONGITUDE   LATITUDE
# 0   686779.4781 -86.815392  36.217292
# 1   685444.7996 -86.838103  36.213470
# 2   659887.4716 -86.885562  36.142923
# 3   685027.2459 -86.789170  36.212652
# 4   664205.1011 -86.874995  36.154861

# %%
# find out the different request type-- There are 4 different types of Requests.
trash_df_read_requests = trash_df_read["Request"].unique().tolist()
trash_df_read_requests
# Out:
# ['Trash - Backdoor',
#  'Trash - Curbside/Alley Missed Pickup',
#  'Trash Collection Complaint',
#  'Damage to Property']

# %%
# find out the description in different types of Requests.
trash_df_read_requests = trash_df_read["Description"].unique().tolist()
trash_df_read_requests
# Out:
# ['house with the wheel chair ramp, they share driveway, in back driveway. 3817 Crouch Dr near NES light post is. \r\n615-876-6274',
#  'Curb/Trash miss Tuesday.',
#  'Curb/trash miss Tuesday.',
#  'missed',
#  'Missed the even side of the road.',
#  'left trash cart in middle of driveway instead of at the backdoor pickup spot',
#  'Trash/emptied Wednesday & now metal black-mailbox damage. \r\ncustomer wants call back and fix and replace.',
#  'Trash out on time, miss again Tuesday. ALLEY',
#  'Missed.',
#  'Trash missed Tuesday again, ALLEY',
#  'Missed trash pickup - resident has at curb for pick up today \r\nreceived back door form on 10/30/2017 is still in interoffice mail pickup since 10/30',
#  'Missed- 4th week in a row.',
#  'Missed. Does not have access to alley.',
#  'trash truck took cart \r\n3 guys on truck did not have truck number \r\nplease call (615) 569-4994',
#  'Pickup missed',
#  'trash carts all tossed in road after pick up',
#  'Curb/Trash miss everyone already gotten pick up. UNIT-B',
#  'Curb/trash miss for this address and others. Tuesday',
#  'A resident is complaining that a trash truck ran a red light through a school zone at Davidson Academy. The truck number is 4887AH.',
#  'Our trash was not picked up today, Wed, Nov 1. It was out by 7 am and our neighbors trash was picked up but ours was not.',
#  'Alley trash miss Tuesday, also others as well, out on time.',
#  'Customer says backdoor pickup was missed the past 2 weeks',
#  'Missed pickup',
#  "missed. Neighbor missed as well-say she is at a dead end and she is constantly missed. She understands it is hard for the driver to turn around  but she doesn't want to have to call all the time.",
#  'cust says entire street was missed',
#  'Missed. Cart is still out',
#  '5th time in as many weeks, Metro has not picked up the trash from 3702 Hobbs Rd on our scheduled pick-up day.  This is not my first complaint.  Also my neighbor at 3704 Hobbs has submitted complaints for the same problem.',
#  'Second week in a row for no trash pickup.',
#  'Missed my trash AGAIN.\r\ncheck your records.  I get missed all of the time',
#  'The trash can was missed this week. They picked up the recycling bins next to it but not the trash.',
#  'Missed- several weeks in a row.',
#  'trash missed Wednesday. Curb',
#  'Alley trash miss for Wednesday. Wants cart emptied. Also others \r\n615-293-1573',
#  'Curb trash miss Wednesday, also neighbors as well.',
#  'Curb/Court missed Wednesday. Trash',
#  'missed pick up',
#  'trash missed pick up - others missed in area',
#  'Curb/Trash missed Whole street, check for other streets as well seen carts still out.  Wednesday. Has to keep calling. \r\nwants to know why?',
#  'Curb/Trash miss Wednesday',
#  'MISSED TRASH CHECK FOR OTHERS ALSO MISSED CURB',
#  'Missed says it has happened numerous times and she is upset. wants Supervisor to call her.',
#  'Missed pickup; cust says trash is missed once a month',
#  'New resident, trash missed 2 weeks in a row',
#  'Missed entire alley',
#  'missed the entire street',
#  'Missed pick-up',
#  'Backdoor/miss for last Friday. Does not understand why?',
#  'Trash/Miss Alley # 2088 Wednesday pick up UNIT-B\r\nBetween Page Rd & Heady Dr',
#  'Resident is very upset- Red River emptied only one of the 2 brown carts he had out, truck driver clamps both together all the time, he needs to do one at the time.',
#  'Curb trash miss for Wednesday. Everyone else was emptied. Small business" non- profit',
#  'Missed trash pickup said has been picking up behind the gate for 26 years \r\n(615) 333-0065',
#  'Missed again\r\npicked up everyone except her\r\ndoes not understand why keep missing (615) 753-1696',
#  'Customer says it was missed again',
#  'Our trash (and neighbors trash) has not been picked up last Thursday or today.',
#  'missed pickup',
#  'Trash was not picked up today',
#  'missed trash - others missed in area',
#  'cust says missed pickup again',
#  'Robin Springs Road missed!',
#  'trash out on Tuesday night for Wednesday pickup, other trash cans were emptied, mine was skipped. full needs emptied.',
#  'Trash container out night before pickup in same location as previous 25 years. Trash was not picked up as scheduled Thursday.  Would like trash pick up week as per property taxes. I also see my neighbors trash cans still out. I presume they have not had pickup either. By the way the double negatives in the questions below are confusing. I had bagged garbage, no recycling and no yard waste.',
#  'Curb Trash missed Thursday. Duplex',
#  'Can i get my trash collection started? Online, it says that there are no services started even through I have the trash and recycle receptacles. My trash has not been picked up for a few weeks. Thanks.',
#  'Missed- she said her grandson was over yesterday and he told her it was full. She needs it picked up',
#  'Trash missed last Thursday. Does not understand why? Curb\r\nplease call 513-403-0759\r\nother missed hub tickets ticket # 23455,20137,16881,13660,9921',
#  'missed pick up - please call (615) 519-3192 wants to know why she is being missed',
#  'caller upset states trash never runs that early, alley. Trash/cart full and wants cart emptied. UNIT-A',
#  'not putting carts back where they got them lids left open carts on ground ...2 complaint see ticket CW 904806 \r\n615-975-1015 please call',
#  'Curb 2 trash/carts miss Wednesday.',
#  'trash not picked up on Wednesday 11/1/17. Still there today, 11/3/17.',
#  'Has been in the hospital and waiver expired.',
#  'Missed again. Has had multiple issues with the route. Needs her trash picked up',
#  'missed pick up - others missed in area\r\ncart sits on Farrell Pkwy side of home',
#  'Curb Trash/Miss Thursday.  {Dead End}',
#  'never gets picked up please pick her up has tons of trash {Thursday}',
#  'missed pick up - others missed in area',
#  'missing every other week- resident is upset.',
#  'missed - everyone except his picked up',
#  'missed pick up - said happens often',
#  'While cleaning the alley behind 1619 Heiman St, someone from the crew had a weed trimmer and cut some pine cypress trees that the customer was growing',
#  "Trash/carts sit's on side alley, missed last week.  Thursday still full. {construction but recycle/guys pickup yesterday.",
#  'Missed- neighbor was also skipped.',
#  'Missed',
#  'customer had 2 trash carts, but only one of them was emptied',
#  'file complaint trash is not getting pick up, wants to know why? Wednesday missed again. Curb',
#  'missed pickup for the street',
#  'Says that the crew always leaves the cart in the middle of the road this time they left it in front of the mailbox and the mailman is unable to leave his mail. Would appreciate it if we put the cart back where he leaves it. Called about this last week and they did the exact same thing this week.',
#  'entire street was missed',
#  'did not see or hear truck on Friday',
#  'customer says trash was missed for the entire street',
#  "I have behind the house pickup.  It has been about a month since the last pickup.  This has been going on all year.  I've called many times.   The staff is always nice, they usually tell they will take care of it but seldom does anyone come out.  Both of my containers are full and I live alone.",
#  "this side missed Friday {wants to know why? she's being missed}",
#  'Alley trash/miss last Thursday. Overflowing needs empty. Before this Thursday.',
#  'trash missed almost every week - adv client to bag all loose items',
#  'missed pick up in alley - several missed in area',
#  'BACKDOOR/TRASH KEEPS GETTING MISSED. FRIDAY\r\nopen gate trash/cart is there always.',
#  'others missed in area',
#  'Missed entire area.',
#  'missed pick up - entire street missed',
#  'Missed again BACKDOOR.',
#  'Missed pickup in alley behind 4611 Alabama Ave',
#  'Curb Trash missed for this address and one other. Share driveway 2 carts.',
#  'missed backdoor pick up',
#  'customer says missed trash pickup for the entire street',
#  'Missed- frequently.',
#  'Customer says that her backdoor trash is missed every week',
#  'Missed entire cul de sac',
#  'customer says trash pickup was missed again',
#  'Trash/has been missed often, in court. Wants cart empty before Thursday.  Overflowing.',
#  'Backdoor trash keeps being missed, truck comes on an off day when should be on normal schedule. Thursday. Correct matter.\r\nhas been missed 9 times since 7/17/2017 please call 615-982-6915',
#  'missed on Friday',
#  'Curb/trash miss last Friday. ? wants cart emptied before this Friday.',
#  'backdoor miss',
#  'Trash/miss Friday, ALLEY UNIT-A',
#  'others also missed in area',
#  'paid back door pick  - does not need extra pick up - but wants you to remember this week to pick up on Wednesday',
#  'The whole court miss trash/Friday. Also Roundwood Forest Dr 37013. Curb',
#  'Alley pickup, last Wednesday trash/missed, does not want this to happen again tomorrow the 8th of Nov. ALLEY wants cart emptied and has overflow does not have anywhere else to set it. All bags should be pick up.  {SENDING A REMINDER}',
#  'Curb/trash missed last Friday. Why?',
#  'customer says the entire street was missed',
#  'missed back door - back door',
#  'customer says trash is not being picked up between 101-150 2nd Ave N',
#  "Trash cart is being left in middle of drive way and at times in the ditch and turn over. She's disable and not able to get out and pickup. Please talk to driver.",
#  'Back door missed.',
#  'Curb Trash/miss one side of street, happen every time. Tuesday',
#  'backdoor pick up missed',
#  'Curb/trash dead end missed Tuesday.',
#  'entire street was missed yesterday 11/07/17',
#  'missed pick up - missed block Tuesday bothside of street. Curb \r\nWill call the director of Public Works next time.',
#  'customer says the trash pickup was missed again',
#  'missed back door',
#  'Backdoor/Trash missed 2 weeks in row, Tuesday.',
#  'Curb/Trash miss for pick up Tuesday. Out Monday night and wants cart empty.\r\n\r\nSteve Woodson\r\n615-227-9888',
#  'truck is cutting into yard and damaging lawn',
#  'customer says the trash pickup is missed every week',
#  'cust says missed pickup',
#  'Missed. other homes were also missed on this street',
#  'MISSED AGAIN',
#  'customer says missed pickup every week',
#  'Curb/Trash miss for Wednesday.',
#  'missed pick up Curb Wednesday',
#  'Curb trash miss Tuesday.',
#  'Missed entire side of the street- says there are only 3 houses on that side of the street and he misses them frequently.',
#  'Missed every week.',
#  'missed back door trash last week',
#  'Truck missed trash pick up on Wednesday 8th',
#  "My trash not collected but neighbor's trash was. My address 264 Riverside Dr, 37206",
#  'Missed paid backdoor trash.',
#  'trash missed past 2 weeks',
#  'trash missed pick up\r\nplease note if resident is not using correct cart',
#  'Missed - frequently missed says she is tired of calling every week.',
#  'Backdoor',
#  'missed trash pickup',
#  'Missed for the 2nd week in a row.',
#  'Trash was not picked up at 244 Ash Grove Dr 37211',
#  "For the second week in a row, my trash was not picked up.... I have a video that shows the truck picking up a can 15 feet across the street from mine and then backing down the road and leaving mine. \r\n\r\nMy expectation is that mine is picked up by noon on Friday and a resolution to this issue. If I am not leaving the cart in the right location (at the end of my driveway and not in the street) I am happy to discuss. perform an on site evaluation of my location, the cart is sitting exactly where it has been since 9 pm last night.\r\n\r\nI am happy to be on site during any evaluation to discuss a remedy to the issue but I will not continue to contact you weekly to ask that you perform a job that you are being compensated for with my tax dollars. If my location and service can't continue, then I will find an alternative source and ask for reimbursements from your department.",
#  "failure to pick trash up on 11/10/17-didn't do Southern Way or Daisy Trail",
#  'Trash has not been picked up in 2 weeks. Not picked up 11/3, 11/10 Veterans Day, or 11/11.',
#  'Trash was not picked up on designated day. Metro water contractor BLD frequently blocks my curb.',
#  'The photo attached is only an example of numerous places where small 1yard diameter puddles of glass are left after trash collection days.I have forwarded numerous examples of this happening over the past year to Pubic Works and our Council Member (district 6), but the problem continues.Is it possible for employees of the trucks, upon seeing that they are leaving behind dangerous debris in the right of way, simply sweep this? As it has been explained that this occurs when the equipment malfunctions.The glass debris frequently in the roadway is both litter and creates unsafe driving conditions for various users of the road.',
#  'Curb trash miss for some people, Friday.',
#  'missed pick up - unit C',
#  'Missed pickup for the entire street',
#  'Missed. Entire cul de sac was missed.',
#  'Missed entire court, Trash wants a call back on this matter. Friday.',
#  'missed pickup; customer says the entire street may have been missed',
#  'trash missed - other missed in area',
#  'Trash/cart damage, due to trash/truck that slams cart down really hard now cart has big crack/split on the body of cart, lid is damage hinges broken. Driver of truck needs to be more careful when picking up carts. Also place cart back where they pickup, not leaving them in the street.',
#  "They completely drove by my house Friday and picked up my neighbor's trash.",
#  'Customer says the trash was missed for the entire week',
#  'Missed pick up',
#  'The whole street missed for last Friday/pickup. Curb',
#  'Customer says backdoor pickup was missed the past 2 weeks\r\nsaid He had talked with Kimberly and confirmed paid in full',
#  'Curb/trash miss last Friday. Check for others.',
#  'Backdoor/miss last week Thursday. Caller wants to make sure all garbage is emptied because of the overflow caller has.',
#  'Backdoor miss',
#  '8 houses missed last Thursday, Every other week this street gets missed often. Thursday. Curb',
#  'MISSED AGAIN - missed 3-4 times in past 2 months',
#  "Backdoor/trash will be pickup this Wednesday, {but will be going to Fl. and won't be coming back until Jan 31st. He will not have any garbage there until he comes back. So please do not cancel his backdoor/trash still in need. Until Jan 31st. \r\n{Not a missed reminder} only {read notes}",
#  'Missed trash for the entire street',
#  'Missed pickup again for the entire street',
#  'customer has back door pick up - received letter in interoffice mail at 750 s 5th st\r\nwaiting for pick up. please do not forget to pick up trash on this Thursday 11/16',
#  'MISSED PICK UP - OTHERS MISSED IN AREA',
#  'Customer says the street was missed',
#  'missed pick up - missed entire street - \r\n(615) 366-5864',
#  'missed back door trash - missed 2 weeks in a row',
#  'only picked up 1 of 2 carts',
#  'resident attempted to talk w driver about possibility of cart falling into truck last week\r\nsaid driver very mean & disrespectful 615-525-3928',
#  'Missed. Neighbors were also missed.',
#  'resident house sitter missed pick up date - request extra pick up',
#  'missed pick up - everyone on street picked up except her',
#  'missed trash for past 2 weeks',
#  'Missed trash pickup',
#  'Missed - resident is  curious why ?',
#  'The whole cul-de-sac curb missed for Tuesday, even talked to driver he said to caller he would be back and did not. Cul de sac missed.',
#  'Pick up at the backdoor.',
#  'Missed- trash/carts curbside {Tuesday}',
#  'cable lines pulled from house - caused damage to roof has pictures\r\ncomcast on site repair line itself but roof has damage',
#  'Complaint with trash/driver that was working for Wednesday pickup, cal de sac reckless with what trash/driver is doing and very rude. {overflow also he seen her coming to talk to him and he just left. Trash/curb only emptied half way.',
#  'picked up everyone on street except her cart',
#  "cust says his and his neighbor's trash was missed",
#  'Curb/trash dead end missed 2 weeks in a row',
#  'Recycling and trash did not get picked up on Veterans Day, website said it would be picked up the Saturday after.',
#  'missed trash pick up',
#  'The trash trucks in their area have been leaking hazardous waste since the summer. She and several neighbors have called about it. It smells badly and the rain does not wash it away.  They are afrais that their children and pets will get into it. Not sure if the leakage if from the trash or the truck. There is a bunch at the bottom of her driveway now and she is afraid to let her son outside. Their hauling Co. is Red River.',
#  'Curb trash miss for Wednesday. Needs to be emptied. \r\nGate code  # 4812',
#  'Caller states trash truck went flying fast through there and skipping his 2 trash/carts. Curb Thursday. both sides of her already pickup.',
#  'backdoor miss Wednesday. Trash',
#  'Curb address has been missed please pick up.',
#  'trash cart empty',
#  'Trash picked up this morning and driver dropped empty can on its side blocking the sidewalk where School children walk to Wright Middle school. Why does the trash driver not get out of his truck and stand the can up?  McCall Street 37211',
#  "PAID Backdoor/Trash missed, Wednesday. Behind red wood fence that is Not locked. {neighbors trash/cart sit's by there driveway, because it's by the property line, so make sure the truck knows to pickup by Red Wood Fence. Call if any questions",
#  'customer says the drivers consistently do not empty half of the trash carts in the area',
#  'Trash backdoor missed.',
#  "Missed often trash missed AGAIN.\r\ncheck your records.  Next to High-School {Curb} Wednesday's pickup. & not a Thursday.",
#  'missed pick up - neighbor calling',
#  "BACKDOOR/TRASH KEEPS GETTING MISSED, WEDNESDAY'S. CUSTOMER WANTS TO KNOW WHY?",
#  'missed pick up..caller req trash be picked up before Saturday',
#  'Curb/trash/ missed Wednesday. Night before',
#  'trash driver going way to fast in reverse, never slow down & paid attention to make sure that people were out walking their dog, upset caller and wants supervisor to talk to this driver and he needs to be slow down, he was at the dead end at the time, going in reverse. They yell at him and he put his arms up like he just did not care.',
#  'Backdoor/trash miss Wednesday. Needs Emptied',
#  'Missed Tuesday, curb UNIT-B both neighbor in UNIT-A as well.',
#  'said never gets picked up - said trash building up & overflowing for weeks - previous tickets closed out & not picked up. Back door waiver is current 8/1/2019\r\nplease note if something is not compliant',
#  'only emptied one of her carts',
#  'cart ran over by trash truck but did not damage cart - truck driver speeding down alley and leaving trash behind & does not put carts back where they got them',
#  'Missed curb trash Wednesday.',
#  'Trash missed on the street',
#  'Curb seems the whole street missed Wednesday.',
#  'cust says multiple houses were missed on the street',
#  "Alley trash/miss Thursday's. #200",
#  "Alley  trash/miss Thursday's. #200",
#  'customer has 2 trash carts and only one of them were emptied',
#  'Trash/Truck is leaving lots of oil on the streets of Eldon Ct and through the sub-division. Look bad and wants this to be clear out and also to let someone know to check there trash/trucks for repairs. Leaving oil on streets.',
#  'said no where to put cart in alley due to fence in way \r\nwants spvr to go look & call to advise (615) 477-8677',
#  'Extra trash pickup, truck came and left his cart. Alley\r\nalso construction going on around there, and he had set small sticks of limbs but took them out.',
#  'cust says trash was missed again',
#  'missed past few weeks',
#  'back door service missed - has overflow due to miss',
#  'trash truck threw cart into the middle of the road and left it there',
#  'picked up everyone except her',
#  'customer says missed trash pickup for the street',
#  'cust says trash pickup was missed for the past 2 weeks',
#  'missed pick up {check for others}',
#  'Had trash at road last night but still missed pickup this morning',
#  'cust says trash was missed for the entire neighborhood',
#  'cust says trash was missed',
#  'They skipped my house for trash pickup',
#  'Hi, not only was my recycling not picked up the beginning of this month (not were my neighbors on the same street), but my trash was not picked up this last week.  I left it out through today, Saturday, figuring perhaps there was some kind of error or delay, but when it was not picked up this morning either, I figured it was time to reach out.  I tried calling the number, but nobody is in the office Saturday?s. \r\n\r\nPlease let me know when both will be picked up and I?ll have them both back out and curbside.  \r\n\r\nThanks!!',
#  "Upset trash/out night before and still getting missed, Friday's. Curb {Trash} Complaint 2 weeks. Wants cart emptied.",
#  "Complaint wants backdoor/trash pickup before Friday. Overflowing and it's backdoor. Emptied before.",
#  'said no access to alley - TRACI system show alley pick up \r\nplease review & advise & pick up at curb',
#  'missed trash - back door Tuesday 2 weeks in row.',
#  "She has been missed multiple times. She doesn't want us to go back to get her trash this week but she does want to alert the supervisor that her trash gets missed frequently.",
#  'The whole street miss for last Friday. Trash wants carts to be emptied before this Friday.',
#  'Missed- trash pickup',
#  'Missed for weeks in a row.',
#  'Missed. States has been missed twice in two weeks.',
#  '626 40th Ave N - Clifton Ave Market- 4 trash carts are full and need to be removed because nobody is claiming the carts.',
#  'missed backdoor pickup',
#  "collection complaint, caller states driver of trash/truck leaving carts everywhere, but the place where they pickup. Upset now carts are gone. Want's to file a complaint because people have to pay for them if lost or missing.  {Talk to drivers}",
#  'missed pick up - back door',
#  '3554 Gondola Dr. Missed one side of the road.',
#  'customer says half the neighborhood was missed',
#  'knocking cart over after pick up - resident is disabled and not able to pick up\r\nplease go back & set up right for resident. \r\n(we have mailed back door waiver form)',
#  'Missed carts. Says her carts sit on Ann St- She said she constantly missed so she would like for the problem to be corrected.',
#  'Thanks to trash pick-up crew for their patience in dealing with a lawn service that had blocked the alley.  They were patient, and talked to the lawn service to get the alley cleared.  I appreciate it!',
#  '2 trash/carts curb, full carts. Needs to be emptied. Truck already came and skip this address.',
#  "Customer does not understands why trash-truck bent mail-box again today. Damage mail-box won't close mail will get wet if it rains. {Repair/Please} 2nd time if any questions call her. \r\n615-876-9325\r\nJudy Cooper",
#  'missed several times - please do not forget tomorrow',
#  'Customer says dumpster pickup was missed at the Enclave At Hillsboro Village for two weeks in a row and wants a call back at 615-269-6460.',
#  "2867 Creekbend Drive - 37207 - My trash NOT picked up today. My trash was at the end of my driveway by 7:15 a.m. this morning.  I left out about 8:10 and the truck was coming down the opposite side of the street so I thought I was good.  When I returned 30 minutes later, the trash was still there.  So I thought to myself, he'll be back.  Well, he did come back but left my trash untouched.  I know he came back because the trash of my neighbors on this side of the street was picked up.  WHY!",
#  'MISSED TRASH ALLEY TUESDAY CHECK FOR OTHERS. UNIT-B SIDE.',
#  "Seems the whole street missed {Trash} curb. She's elderly",
#  'Curb Trash keeps getting missed, the only house there, across from the Church, does not understand why trash is missed often. Tuesday. Out by 4:00 a.m. {Complaint}',
#  'Has been missed for the 2nd week in a row. Would like to be picked up on route.',
#  'Trash was not picked up last Thursday, making sure I am added to the route, the physical location is on 2314 9th ave S Nashville TN 37204',
#  'Trash pickup Tuesday',
#  'Backdoor/Trash miss for Tuesday. On the list for backdoor.  Sent waiver back. \r\n615-969-0641\r\nHenry Dozier',
#  'Curb trash/missed often Wednesday. Caller upset and wants cart emptied. File complaint. Wants this matter corrected',
#  'customer says the trash is usually missed every other week',
#  'Our trash was not picked up today',
#  'They missed our street on Wednesday 11/22.',
#  "November 25, 2017  -  Saturday\r\nTrash collector knocked my trash bin over in my yard instead of emptying it spilling it all over my front yard and didn't bother to pick up the bin.  Everything was in bags until the dogs and wind got to it.  Who does that kind of crap?  Especially when we've missed a pickup for Thanksgiving.Our trash is overflowing.  Please send someone to pick it up before Thursday. I've cleaned all the trash out of the front yard.",
#  'MISSED - others missed in area',
#  'back door pick up - said truck drove over 2 lights in driveway broken off',
#  'cust says the entire street was missed',
#  'Missed. Carts on the corner of Kirkwood and Belmont Blvd.',
#  'Missed backdoor trash pickup.  UNIT-B',
#  'cust says pickup was missed',
#  "Trash/miss for Saturday's pickup, ALLEY {check for others} missed.",
#  'Alley trash pickup, has 2 trash/carts but only one gets emptied all the way, 2nd trash/cart does not. This happens all the time and wants this matter to be corrected.',
#  'MISSED PICK UP  - OTHERS MISSED IN AREA',
#  'MISSED PICK UP - PICK UP IS ON 9TH AVE S SIDE OF HOME\r\nNO ALLEY BEHIND HOME - PLEASE REVIEW TRACI & MAP',
#  'customer says this was missed for the street',
#  'customer says missed pickup',
#  "Curb trash/out by 7:00 a.m. {one driveway for 2 houses and both getting by pass every week. Has to call in. Upset and wants to speak with higher up. Wants this matter corrected. Pick up trash/on Thursday's like it should. {week after week} why?\r\ngave R/R number",
#  'ref 298388 / cw 939492 is not satisfied with repair of mail box hit by trash truck \r\nplease call asap \r\n615-876-9325 or 615-496-7934 cell \r\nJudy Cooper',
#  'Saturday Trash curb missed',
#  "Big concrete Lion has been knock off into the ditch, never had any problems before with the old driver, whom ever came on Friday for backdoor/trash/pickup should have damage on trash/truck.  Just want higher up to know and needs to be address, they are not able to pickup because it's heavy and health reasons. Please investigate.  {a paw/foot}. Fallen off drive, little damage to lion just wants to know. Should of been reported.",
#  'Backdoor/Trash miss for Tuesday - previous ticket closed out\r\nresident said no white van on property - next door neighbor has white van \r\nbut they do not share driveway \r\n"MANGRUM, JOSHUA W: 11/25/2017 6:22:44 AM\r\nTHE CART WAS BLOCKED BY WHITE VAN OM SERVICE DAY. PICKED UP BY R. BRADY"',
#  "customer says there's two trash carts for units A & B, but each week only one of the carts are emptied. customer says they never empty both carts.",
#  'Missed resident is upset, would like explanation as why her trash was not picked up. Customer has pictures that trash was complaint.',
#  'several missed. States she is missed multiple times a month',
#  'Missed backdoor.',
#  "Missed backdoor. Mentioned Someone lives downstairs who's trash cart is put out on the curb but she lives upstairs and has backdoor trash.",
#  'Missed carts. Says her carts sit on Ann St- She said she constantly missed so she would like for the problem to be corrected.\r\n\r\nTRACI shows Alley Pick up said does not have access to Alley that park is behind home - said alley  does not exist behind home - please review & advise',
#  'said accidentally put lots of important papers in trash in yellow plastic bag \r\nwants to retrieve - called prior & was given Red rivers phone number and they are not answering - said very very important that she might be able to retrieve',
#  'has been missed many times overflowing.Has backdoor pickup',
#  'not emptying cart all the way leaving trash behind all the time',
#  'missed pick up - picked up neighbors & missed her cart',
#  "West Hamilton side is where trash/cart will be set. {Driveway is there}\r\nmother's waiver was cancelled, will send waiver back she's in hospital.",
#  'cust says this address was skipped',
#  'Missed often- trash missed AGAIN...caller states this is happening habitually.',
#  'Missed. Trash has been missed twice in 2 weeks. Entire Coda-sac has not been picked up.',
#  "customer says the drivers yelled at her husband and were upset about where he's parking his car. the parking location may be causing an issue with the pickup",
#  'cust says pickup was missed for one side of the street, but not the other',
#  'Missed- Backdoor',
#  "Customer states garbage-men when picking up cart, spilled one of her bag and everything fallen out into inside cart. She want's cart to be emptied correctly now trash/is still inside. Emptied Cart {ALLEY}",
#  'Customer has 2 trash carts are one was missed',
#  'customer says missed backdoor pickup each week',
#  'None of the Trash was not picked up on Wednesday  on White Oak Drive 37215.',
#  'My trash and a few of my neighbors trash was not picked up today. Not sure why. no notes or anything. All of us had them out last night and left them out all day.',
#  'trash not picked up curb/unit#301',
#  'Put Happy Holidays card on cart & did not pick up trash',
#  'did not empty cart fully - wants trash emptied all the way',
#  'backdoor/trash miss for Wednesday.',
#  'cust says missed pickup for all the residents on the other side of the creek',
#  'Curb/Trash miss for pickup, 2 carts out.',
#  'cust says missed pickup; cust says its appears the entire street was missed',
#  'Trash missed',
#  'Missed. Does not have access to Alley. Curb side only',
#  'Missed. States trash has not been picked up for 2 weeks. Only house that has not been picked up.',
#  'cust says missed pickup. Has backdoor pickup',
#  'missed pickup for the entire street',
#  'Says that the trash collector in his area always leaves the carts allover the roadway and in the ditch- this is causing damaged to the carts and it is also a safety hazard when they are in the middle of the roadway. Would like to see the guy take his time to put the carts back in their place.',
#  '2 carts are full  - others missed in area',
#  'Missed Trash Pickup',
#  'Missed entire street',
#  "Only one side of the street was service, missing their side, Thursday's pickup. Check for others.",
#  'Missed trash pickup. Caller stated her neighbors also wasnt picked up.',
#  'Mrs Mc Cann stated the Saturday after Thanksgiving her trash was piicked up and the trash truck broke down in front of her address.  Another truck came to help by spreading sand all over the spill. Now it is a big mess. Customer wants someone to come out and clean up the area.',
#  'Paid Backdoor- missed. Cart under the tree in the front yard.',
#  "Dead End street not pick up for Wednesday's pickup. Curb",
#  'missed pick up - others missed in area\r\npick up on 26th ave side of home',
#  'Missed- entire street still has carts out.',
#  'Trash cans on our street were not collected on Wednesday, November 29.',
#  'missed pick up - picked up everyone except his cart\r\nsaid 6th time in past year',
#  "customer is upset that the truck pulled into her driveway behind her car and backed out of her driveway in order to continue his route. The customer doesn't want the trucks pulling into her driveway",
#  'missed back door pick up',
#  "Tuesday's curb miss for two weeks now. {been out since last week}. {other business shares those trash/carts, total of 3 carts.",
#  'Truck some-how got caught to the wire line, of some sort. Utility line. Just so someone knows about this. Be Recorded {wire is hanging very low} beside the house cul-de sac. {Safety Hazard}',
#  "Curb not pickup on one side of street. Wants cart emptied asap. Thursday's pick up",
#  "PAID Backdoor/Trash missed, Wednesday. Behind red wood fence that is Not locked. {neighbors trash/cart sit's by there driveway, because it's by the property line, so make sure the truck knows to pickup by Red Wood Fence. Call if any questions  {No cars blocking driveway. needs to be emptied.",
#  'others missed in area also\r\nsaid has happen a few time lately',
#  'curb trash miss for last Friday.',
#  'Whole street miss last Friday, trash curb.',
#  'Curb trash miss last Friday.',
#  'customer says work was being done in the alley and the ramp going into his garage was damaged',
#  'Everyone has carts out still, on Lishwood Dr. Friday missed. Dead End Curb. This is the 3rd time this has happened.',
#  'missed trash pick up- caller states this happens frequently-',
#  'cust says trash pickup was missed for the entire st',
#  'cust says once trash is collected, the carts are left all over the street',
#  'missed trash on this side of entire street',
#  'cust needs a backdoor pickup',
#  'Missed 2 carts full',
#  'Curb Trash corner of street, truck always seems to pass them up. Wants this matter to be corrected. Call many times as well. Wants to go to higher up on this matter.',
#  'picked up everyone except his cart 3rd week in a row',
#  'backdoor trash missed',
#  'PAID Backdoor/Trash Missed for 3 weeks or more. Thursday {wants cart emptied} correct this matter. PAID BACKDOOR MISSED',
#  'missed pick up for the past 2 weeks',
#  'Mail box damage by trash/truck {rod-iron mail box with metal box} needs to be repair asap. This happen last Tuesday. Neighbor seen them.  {Wants a call back or just come and replace mail-box.',
#  'missed pick up- all neighbors carts were picked up',
#  'Says the trash was missed in the 900 and 800 blocks of Lischey Ave. including his.',
#  'paid back door service - said driveway is new and wants trash representative to not take truck onto driveway 30 days and instead to have then walk down driveway and pick up trash manually - please call 615-832-0797',
#  'Very upset resident wants a call from the Supervisor today. 615-353-4771',
#  'cust says missed for the entire street',
#  '1 trash cart was missed.',
#  'Curb trash miss Tuesday. Needs to be emptied.',
#  'Missed- Trash',
#  'Missed- Backdoor pickup',
#  'missed pickup; 513 Fisk St Unit A',
#  'not putting cart back and tossing onto ground',
#  'Resident did not get cart out on time - need extra pick up',
#  'Curb trash Tuesday, missed also check neighbor across the street also missed.',
#  'Caller stated that the person picking up trash today on his street has broke several lids and throwing trash all down the street.',
#  'emptied neighbors carts and not his',
#  "Caller states that the trash carts from the Bristol West End Condominiums  are blocking the alley. Callers driveway is in the alley and once the trash carts are brought out he can't access his drive and the whole alley is block until trash carts are emptied. This alley is at the corner of Vanderbuilt Place and 29th Ave S",
#  'fraud Green post card in mail box that was not mailed but placed in mailbox \r\neveryone in neighborhood - talked with Red River driver said not them. Post card size said from "Trashmen"  please mail all gift & blessings to Po box 2235 Goodlettsville tn (no zip code) \r\nalso ruby 615-298-1797 or  greg riechert 292-9697',
#  'Did not empty cart but left Christmas card.',
#  'missed pick up- caller states it appears that some of trash was picked up but not entire contents of cart',
#  'MISSED TRASH ALLEY TUESDAY CHECK FOR OTHERS. UNIT-B SIDE.\r\nCaller watch them go to alley not picking up some carts. Cart is out. {Wants cart emptied.',
#  'picked up neighbors & skipped over her cart \r\ncart sits on Highland park  side of home',
#  'Missed pickup-this is an ongoing propblem',
#  'It looks like the trash was picked up on one side of the street but not the other',
#  'Continuously Missed.',
#  'Trash schedule pickup Wednesday?s, not picked up. When should we expect it to be picked up?',
#  'Curb/miss Tuesday needs to emptied.',
#  'New home no alley access have cans and am registered for Wed.  Can rolled out in driveway.  No pick up twice now.  Getting out of hand.  Can is very very full need pick up.',
#  'Missed - Backdoor needs pick up {Wednesday}. Reggie needs to get envelope for Christmas and no other but him. Also pickup his garbage.',
#  "Caller states trash/men where digging very hard through her neighbor's trash/cart. Like if they where looking for stuff. She did not like to see this. Just wants higher up to know about this. Across the street from this address",
#  'cust says trash missed',
#  'MISSED TRASH CHECK FOR OTHERS ALSO MISSED CURB. 12 condos all may have been missed',
#  'Backdoor/trash miss Tuesday. Overflowing',
#  'Curb/2 Trash miss {Wednesday} Wants cart emptied today.',
#  "customer says the driver drove by his home and emptied everyone else's trash except his for 2 weeks in a row",
#  'Trash has not been picked up for the last 2 weeks.',
#  'cust says pickup was missed for him 3 weeks in a row',
#  'In the last 3-4 months, my trash has NOT been picked up 3-4 times and I have had to submit a request for someone to pick it up.  I receive an automatic reply which states that it will be picked up in the next 2 days.  Thus, the trashcan sits out on the street for up to 3 days.  I would like for someone to provide an explanation as to why this problem is suddenly occurring.  I have been at my residence for 27 years and have not had this issue until recently.  Thanks.',
#  'caller states 3rd week in a row no trash pick up',
#  'cust says trash has been missed for 3 weeks in row at 2811 DELAWARE AVE unit A',
#  "cust says pickup is usually missed every other week. says the truck doesn't always come to the dead end area where her address is.",
#  'cust says it is missed once a month',
#  'Missed. Resident has been missed every other week.',
#  'Missed-Trash... Customer says trash has been missed several time in the last couple of weeks.',
#  'Missed- trash',
#  'Missed-trash',
#  'compacting trash in front of home leaking juice & debris & glass \r\nwants cleaned',
#  'because cars park on the side of the street, cust says trucks need to make sure that carts are placed back on the side and not in the middle of the street after being emptied',
#  'MISSED TRASH ALLEY TUESDAY CHECK FOR OTHERS. UNIT-B SIDE.\r\nCaller watch them go to alley not picking up some carts. Cart is out. {Wants cart emptied.\r\nprevious ticket Hub 31933 / PW 943535 said cart not out - resident very upset \r\nwants call 615-732-9249',
#  'trash missed',
#  'Would like to request that the driver place the carts off the alley so that they can access their driveways without having to step out of the car to move them out of the ROW. Says this has been an ongoing issue.',
#  'missed. Has 1 trash cart. IS ON CORNER OF 3RD AVE AND CHURCH STREET',
#  'Customer said when her trash was dumped today some of the bags fell off in front of her driveway and she had to leave work to clean up mess.',
#  'Has been missed continuously since July.',
#  'Missed backdoor - bothered he has to call instead of the problem being fixed.',
#  'cable box on the side of the house was damaged',
#  'trash was missed for the street',
#  "cust says she's frequently missed",
#  'Trash/miss for 2 week in a row, ALLEY Wednesday. Other neighbors as well. Wants carts emptied.',
#  'Missed.-trash',
#  'trash was not picked up again',
#  "Missed- says is constantly missed. He is irritated because he sees the trash truck ride by his house but they don't stop. Curbside pickup.",
#  'Missed- Trash Unit A and B were missed',
#  'Trash/truck came before 7:00 a.m. it was 10 mins before 7:00 a.m. when she seen trash men passing, Caller states her cart would of been out by 7:00.  If truck would of not pass before 7:00.',
#  'SOMEONE STOLE TRASH CAN AND DUMPED GARBAGE AT TLOCATION, OWNER NEEDS NEW CAN AND ALSO HAS BAGGED TRASH IN BAGS TO BE PICKED UP ON NORMAL ROUTE THIS MORNING. CAN SOMEONE PLEASE CALL THE OWNER PW CUSTOMER SERVICE TO FOLLOW UP WITH OWNER PLEASE.',
#  'Missed- Trash\r\nadded notes by G. A. upset never had a problem until recently. He was told everything has to be in trash/bags. He just wants this pick up.',
#  'missed pick up - others picked up in area - skipped his cart',
#  'Trash/Truck damage big plastic mail-box, her elderly mom seen him & talk to driver of truck. Trash/driver try pushing post back in ground but could not. So now mail-carrier can not deliver any mail until the mail-box is repair. {big plastic mail-box with concrete needs to be install back with cement materials. As Soon As Possible, call her is any questions.',
#  "hasn't been picked up in a couple of weeks. Trash is overflowing.",
#  'cust says that their pickup is often missed and that sometimes the truck knocks trash carts over causing trash to spill out into the street',
#  'missed pick up but picked up neighbors. caller states this is 2nd week in a row trash was missed. Has 2 weeks of trash in cart.',
#  'trash truck knocked box off mailbox post- caller set the box on mailbox post but it is not fixed. caller thinks it can be fixed with same box and post.',
#  'missed. Has 2 trash carts',
#  'missed pick up - everyone picked up on street except her carts',
#  'cust says missed pickup for two weeks in a row',
#  "cust says trash hasn't been picked up in 2-3 weeks",
#  'cust says missed pickup;',
#  "CUSTOMER VERY UPSET THE TRASH MAN CAME EARLY AGAIN BEFORE 7 AND WHEN SHE CALLED IT ROLLED TO OEM A T 7:02, SHE STATED THAT IF NASHVILLE HUB ISN'T GOING ANSWER AT 7 AM THEN THEY NEED TO CHANGE THE WEBSITE TIME, SHE STATED SHE WOULD TRY BACK AND ASK FOR A SUPERVISOR, WAS UNABLE TO GET HER NAME",
#  'Missed. {Cart sits on Cherokee Ave side}.',
#  'trash was not picked up again 2x time in 3 weeks',
#  'Missing.',
#  'missed pick up- cart is full.. this is not the first miss',
#  'Cart still out- says she has been skipped and this has been an ongoing issue.',
#  'missed pick up- this is the 2nd week-cart is overflowing-this is a new construction which is occupied-others nearby are not- alley is next to 1412 boscobel st.',
#  'customer says the trucks keeping missing trash pickup',
#  'caller has 2 standardized issued carts- for past 2 weeks only one cart has been picked up and emptied.',
#  'Trash was not picked up',
#  'caller has had backdoor waiver pick up since aug 2017- caller states trash is not getting picked up at backdoor (side of house) as it should be-caller is elderly and disabled.',
#  '2nd week in a row missed collection.',
#  'Backdoor/Trash pickup was missed',
#  'I have the ADA backdoor tradh pick up, and I was missed today. The addy is 4113 Lone Oak Road, Unit E, Nashville 37215. The unit is in the front. Thank you. M. Wagner',
#  'Trash bin was on street Tuesday night for Wednesday pickup and was missed.',
#  'I have 2 containers they picked up the less full one & left the full one. It is not really a complaint Just wanted you to be aware',
#  'Curb/trash miss for whole street no pickup for Tuesday. Out night before needs to be emptied. \r\n\r\nAngela Jones \r\n615-557-5724',
#  'Trash/Curb miss for Wednesday.',
#  'MISSED TRASH CHECK FOR OTHERS CURB. All 12 condos have been missed.',
#  'Missed. Drove right pass home and this has been 2 weeks in a row.',
#  'missed pick up-',
#  'Missed needs pick up',
#  'Trash out in time yesterday but for some reason our Can was overturned and the trash not picked up.',
#  '8 Carts in the alley for 524 and 526 26th Ave N. They have not had trash pick up in a couple of weeks. Wondering if they are doing something wrong. Overflowing. Needs pick up',
#  'missed pick up- all neighbors was picked up',
#  'Missed. Entire street was missed',
#  'Alley trash keeps getting missed very week and wants to know why? Brown/Cart everything inside plastic bags and wants carts to be emptied. This week and not want to call back. She seen truck already passed today. {also wants a call back today}',
#  'Missed. Cresent and Clearview Dr both streets were missed.',
#  'caller has video footage of trash collection truck knocking over her cart which emptied trash onto property/street. Then truck drove off.',
#  'missed pick up - everyone picked up around them',
#  'metro trash truck pick up at the house next to the day care and he bumped into their fence. Damaged fence at 4430 Winston Ave W',
#  'information on how many & what names picks up her trash from back door\r\n615-714-6915\r\nwants to remember them on the holidays',
#  'cust says a lot of carts were not picked up',
#  'Missed. Resident is upset.',
#  '3424 hamilton church rd is not getting the trash pick up service. I have called twice and yet nothing has change.',
#  'Missed- Dumpster pick up',
#  'Missed- Trash. Customer said the entire street from gas line break.',
#  'Missed others missed in area',
#  'cart is being missed once a month and need to get on route',
#  'Our street was missed yesterday in trash pickup.  Entire block still has bins - some very full - still waiting to be emptied.',
#  'missed trash',
#  'Trash repeatedly not collected due to alley being blocked by adjacent construction crew.',
#  'Missed. Cart sits on Oakley Dr and Oakley was missed.',
#  'Has been missed twice in a row.',
#  'Alley trash miss for everyone, out night before. Wednesday. {They come every other week it seems.',
#  'We live at 905 N 12th Street, 37206. We have placed trash and recycling outside that has not been picked up while our neighbors on both sides of the street have.',
#  'Curb trash/miss for Thursday. Needs to be emptied.',
#  'mail box knocked over',
#  'The trash truck hit our car on Thursday afternoon. He hit our next door neighbors car and the police were called our address is 543 Bonerwood dr Nashville, to 37211',
#  '3648 Woodbridge Bridge Dr. Nashville  37217  My side of the street was missed. My trash bins are still on the street',
#  "We noticed our trash and recycling wasn't picked up this morning.  We watched the footage from our camera and they literally just walked past our cans and didn't do anything.  Can we have them come back get our recycling and trash?  This isn't the first time we have been skipped.",
#  'MISSED 6154802891',
#  "Trash/missed last Friday, ALLEY**passed two Friday's. SINGLE FAMILY HOME",
#  'Missed. Has 2 carts',
#  'missed. Has 2 trash carts\r\nback door waiver on file effective 12/11/2017 good to 12/11/2019',
#  "Trash/miss last week, curb. Not emptied and doesn't think cart was blocked?  Tuesday. Make sure it's emptied for this week of Dec 19th.",
#  'Missed. Trash is full. Multiple houses missed',
#  'missed pick up for unit A at 1601 eastside ave',
#  'missed cart sets on martha',
#  'Back door pick up \r\nsaid never gets picked up - said trash building up & overflowing for weeks',
#  'said had 2 carts out full of bagged trash - 1 cart missing & the other was not emptied\r\n(615) 975-4989\r\nsaid no A&B unit',
#  'mailbox hit by trash truck and now it wont close',
#  'My trash was not collected on the scheduled day/time.',
#  'CART STILL OUT',
#  'missed backdoor pick up for the past month.',
#  '1133 Kirkland Ave & pickup on Windsor Ave side.  {Curb/Trash} Tuesday.',
#  'said red river truck is emptying both trash & recycle carts into trash truck\r\n(615) 298-1797',
#  'left message on cart for driver to come to door so they could wish happy holidays\r\nupset they did not come up to home',
#  'only emptied 1 of 2 cart\r\nbackdoor pick up',
#  'Curbside-Missed frequently and has to call.',
#  'Trash bins not picked up on Ireland St, Nashville, TN 37208\r\nentered on web did not give address - please check all others on Ireland St',
#  '2nd trash cart fell in truck',
#  "Missed. needs pick up- says hasn't been picked up in weeks. She will have her cart on the sidewalk at the end of her driveway on westbrook.",
#  'Missed entire cul de sac.',
#  "Trash backdoor missed. Check TRACI showing Wavier Termination 11/08/2017 & then new Waiver 11/17/2017 and than Waiver Termination 11/29/2017. Customer does not understand why it's been cancelled again. She sent everything under her name. Call her back please.",
#  'Trash did not get picked up today. Very full.\r\n6045 Cargile Road 37205',
#  'Trash not picked up 12/20',
#  'cart still out got everyone else but left hers 25 bosley oaks',
#  'corner houses were missed 305 st james park',
#  'Curb trash/missed Wednesday. Need to be emptied.',
#  'Alley trash miss again, dead end. Wednesday.',
#  'missed entire street',
#  'missed several weeks',
# ...
#  "Our trash dumpsters were left in front of our mailboxes today; therefore, the mail person is unable to deliver our mail. Also, each week the gentlemen that remove our trash leave our dumpsters wherever (typically out in the road with lids open). Why don't we have automatic truck pickup anymore? Thank you for looking into this situation.",
#  'got everyone elses but hers',
#  'Missed Wednesday Curb',
#  'Trash did not pickup garbage, Wednesday. ALLEY',
#  'trash has been missed for the past 3 weeks- cart is full- Backdoor pick up.',
#  'truck hit fence & damaged it - this is 2nd time that they have damaged fence \r\n(615) 228-5192',
#  'Trash/miss for Tuesday {ALLEY}',
#  'picked up everyone except her cart',
#  'backdoor missed. missed weekly',
#  'got everyone but hers',
#  "705 tina ct didn't get this court",
#  'Backdoor/Trash miss for pickup Wednesday.',
#  "Customer says that the crew is not empty his trash cart completely. He said has been for the last 3 weeks the cart has been left about 3/4 th of way full. Either the arm is not tipping the cart enough of crew doesn't know how to work the equipment per customer",
#  'Trucks leaking oil and fluid all over the roads. Leake Ave and Lasalle Ct',
#  'side of the street was missed',
#  'side of the street was missed two weeks in a row',
#  'back door pick up - said manager was to call her back has not had service in over 2 weeks - wants call now, wants picked up now ! escalated to call cntr spvr\r\n\r\nsee hub # 38425',
#  'Trash not picked up',
#  'Trash not picked up again',
#  'trash pickup missed on 1/18/18',
#  'Trash missed again. Customer is upset wants trash picked up',
#  'cust says the cul de sac was missed',
#  'I called inquiring about the trash pick up on 1/16/18 due to the weather and I was told they would pick up on Saturday 1/20, but when I get home on 1/19, trash pickup on our street had already run. Now our trash can is too full to add any more trash that we have.  I went with the information I was given.  Can a run be made prior to our next trash day on Tuesday, 1/23?  Thank you. Jackie',
#  "My trash bin was left completely full after last Friday's scheduled pick-up.",
#  "Complaint. Trash collection was delayed, no trash got collected, there should have been an announcement somehow. If nothing else it should have been on the news, it's public service that we all use! It was delayed because of a snow day, we had it ready for two days, got it back from the curb so it would not get knocked over and spilled. He went by on a Saturday, unexpectedly, so we missed him. Call me for reschedule, this was an ADMINISTRATIVE error. We had no notice of him coming! We are still ready for pickup NOW, it didn't get announced properly, so it didn't get picked up HERE.",
#  'Trash was not collected last Wednesday due to snow. All the carts on the alley are full.',
#  'Our trash has not been picked up since Wednesday',
#  'Trash has not been picked up since 1.04.18',
#  "put trash in wrong can and regular trash wasn't picked up",
#  'Regular trash was not collected for ALL homes on Seasons Lake Court \r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nRegular trash was not collected for any homes on Seasons Lake Court on Jan. 19th. Recycle trash was collected in the morning.',
#  'Trash was not picked up on Wednesday.   Trash can was out before 7am.   Assume it may be weather related but trash can is still at roadside waiting for pickup.   Need to know date it will be picked up so I can place all overflow bags beside can since it has been almost 2 weeks since last pick up.',
#  'The other side of the street was picked up, but our side was not.',
#  'CALLER ADV TRASH TRUCK WENT BY AND SKIPPED HER HOUSE OEM FAXING TO PW',
#  'TRASH WAS NOT PICKED UP SENT TO PW',
#  'trash not picked up (alley) on Friday, 1/19/18',
#  'Recycling was missed 2 weeks ago and no trash pickup this past week. I understand the snow has caused delays. Just want to ensure that the recycling and trash get picked up. We live on a dead end street with 7 houses and tend to get missed at times. Please conform that this message has been relayed to the appropriate personnel. Thank You, Lisa.',
#  'No trash pickup on January 18th on the whole street',
#  'Entire neighborhood to include- Empire Drive woodson lane hewlett  Drive grubbs Drive Got told they would pick up Saturday no one showed up',
#  'carts on oriel still out',
#  'has extra trash by can because we missed',
#  "this end missed this weekend wants a call about why it wasn't picked up on time",
#  'Missed pickup Saturday January 20.  Regular day Jan 17 but bad weather.  Trash was picked up on our street Jan 20 BUT missed our household.  Street was clear and safe that day.  Please pick up trash as soon as possible, thanks.',
#  'CART STILL OUT FOR OVER A WEEK',
#  'THIS AREA WAS MISSED THIS WEEKEND AND TRASH BAGS ARE BEING SET ON GROUND',
#  'picked up everyone on street except his AND ACROSS THE STREET',
#  'Trash and recycling not ticketed up on Wednesday. Snow on street and did not come up Wayland Ct. entire street still has cans out.',
#  'CARTS ARE STILL OUT',
#  'cust says missed',
#  'Missed him  and the neighbor.',
#  'this side of street missed',
#  'Missed trash pick up again. Customer said it is getting to where she has to call every 2 weeks because she now has 2 weeks of trash again not getting neighbors either and is requesting supervisor to call her back.at number on this ticket',
#  'MISSED ENTIRE AREA',
#  'missed pick up for the past 3 weeks- cart is overflowing- carts are located outside gate at end of driveway.',
#  'several on  street missed',
#  'Trash/miss for Wednesday. Due to snow weather {Court missed}- sill has not been pick up',
#  'half street missed',
#  'MISSED trash PICK UP',
#  'wants call 615-545-8636- has not been picked up \r\nsaid 5 carts not picked up at complex',
#  'Trash-missed',
#  'caller has had backdoor waiver pick up since aug 2017- caller states trash is not getting picked up at backdoor (side of house) as it should be-caller is elderly and disabled. This is 2nd complaint and trash still is not getting picked up.',
#  'missed backdoor- trash has not been collected in weeks. Caller states trash cart is on the side of property.',
#  'paid backdoor missed pick up',
#  'missed pick up- missed neighbors as well.',
#  'Missed. Entire street',
#  'Missed entire alley for trash',
#  'missed for the entire st',
#  'the entire street was missed',
#  'this alley',
#  'Trash/alley missed also others',
#  'Trash has not been picked up since 01/10/18.',
#  'cart out',
#  'Missed Backdoor trash pickup',
#  'missed pick up ...missed entire neighborhood.- The Reserve at Eagle Ridge Subdivision.',
#  'cart still out and has trash out on ground because it was missed',
#  '162 lelawood cir',
#  'cust says the trash pickup is not done every week',
#  'Missed half the street closest to Brook Hollow',
#  'Trash pickup did not happen Thursday due to weather and didn?t happen Saturday either. Our entire neighborhood has overflowing trash cans, as do we.',
#  'trash truck is getting into median and damaging it they need to go to end of street or metro needs to pave yard',
#  'backdoor missed pick up for past 2 weeks need pick up asap',
#  'Trash/curb miss, when all others were pickup. Tuesday Jan 23, 2018.',
#  'There has been no trash pick up on Dorcas drive in over a week. They were suppose The come last Wednesday, but I am guessing did not due to snow. I assumed they would come this weekend, but no. All trash cans are overflowing.',
#  'Truck coming up their drive-way every time and backing up. She did notice this and was home and looked out her window they are pulling back into her driveway. Now her driveway is cracked/at the very end of drive-way. Call Mrs. Deanna F. Tiger. 615-944-8921',
#  'picked up everyone exempt for his trash',
#  'Trash/truck busted trash/carts, customer is upset and wants trash/men to be more careful of how they handle the carts. They throw them down all over the road and why they keep doing this. Wants someone to contact him asap. Truck # H-77 {the whole neighbor-hood is bad and wants supervisor to come there and see.',
#  'the cul de sac was missed',
#  'cart out since last thursday has more trash on ground',
#  'Overloaded trash at the North Precinct',
#  'Continue to have issues with our trash not being picked up each week.  Our trash bins are located at the back of the house which we were told is where they will pick up.',
#  'missed pick up- there are several full carts at this address- did not pick up last week.',
#  'missed- trash has not been collected in weeks-overflowing.',
#  'missed- backdoor...caller states if  missed again it will be a month since the last pick up.',
#  'Curb trash/miss for pickup. Last Friday. Over-flowing',
#  'MISSED TRASH PICK UP',
#  'trash missed in alley',
#  'several carts out',
#  "cart knocked i ditch by truck need to come pickup she can't",
#  'The other side of the street was picked up, but our side was not.\r\nwants official complaint that previous ticket closed out not picked up \r\nref 40552 / cw 955205\r\nBy DOOLITTLE, JASON: 01/23/2018 03:03:55 PM \r\nper red river- Wed. pick up will remind driver',
#  'lcart still out',
#  'Trash/Tuesday miss last week due to snow, and this Tuesday also. Curb 2 carts out.',
#  'missed pick up again....please review pick up this is 5th missed pick up since end of November',
#  'Missed. cart is full was out the night before, neighbors trash was collected. has been a couple of weeks since trash was collected.',
#  'missed entire alley',
#  'missed- picked up neighbors trash. this address was the only missed.',
#  'carts on entire alley been missed for 2 weeks',
#  'missed  for past 2 weeks',
#  'cust says his cart was skipped',
#  'Missed-trash. Several in neighbor missed per caller',
#  'Missed- overflowing.',
#  'Missed. on the front stoop.',
#  '2713 Shadow Lane, trash pick up has been missed for two consecutive weeks. Last weeks was due to inclement weather. Curb Monday evening for normal trash service on Tuesday.  The opposite side of the street had their trash collected but never came back for our side of the street.',
#  'My trash has not been picked up in two weeks.',
#  'the entire street missed for 2 weeks',
#  'Trash/Missed for Wednesday 2 weeks now.  Curbside Whole street.',
#  'My trash was not picked up yesterday.',
#  'Whole street miss for Amanda Ave, and trash/cart is set on Amanda Ave for this address. Curb.  1700 Woodmont Blvd.',
#  'CALLER ADV TRASH NOT PICKED UP TODAY (OR LAST WEEK DUE TO SNOW) OEM SENDING TO PW',
#  'no service for 2 weeks needs asap',
#  'miss pick up',
#  'BACKDOOR MISS 6158334002',
#  "Backdoor/trash miss again, been weeks no service. Tuesday's pickup.",
#  'Missed for Wednesday. Curb UNIT-A',
#  'backdoor missed pick up - said paid w online bill pay Capital One \r\npaper payment $276.00 12/22/2017',
#  'Missed- Trash. Caller said it was missed last week. The entire block. He will call every day until picked up. we have no excuse for missing the pickup',
#  "Trash/Curb not emptied Thursday's pickup. Missed the last two weeks {Place of business} Buchi Plumbing",
#  'Need trashcan picked up please.',
#  'Please pick up Trash',
#  'back door trash missed',
#  'Curb Trash/Wednesday, needs to be emptied.',
#  'Missed. Cart is full \r\n\r\n\r\nAllen Doucette \r\n615-568-8931',
#  'missed-',
#  'back door missed pick up for past few weeks\r\ntrash is overflowing',
#  'pickup everyone except his cart\r\nsaid truck came & tipped cart into truck bit did not empty cart ?',
#  'Caller said we got grease all over his cart today from the pickup. Stated he was all over his clothes and jacket. He wants the cart cleaned or replaced.',
#  'Missed all of Cedarhill Ct and Cedarhill Dr',
#  'missed pick up for the street',
#  'trash not picked up',
#  'Pay Backdoor trash missed Wednesday 2 weeks of garbage missed. Needs to be empty.',
#  'Curb trash keeps getting missed. Wednesday.',
#  'Curb trash/miss for Thursday.',
#  "garbage providers aren't doing their jobs. Missed her trash.",
#  'Missed backdoor. States he is missed weekly',
#  'Missed-trash- Neighbor was missed also',
#  'Our trash was not picked up yesterday, and it is full.  Please come empty our trash at the earliest convenience.  Thanks.',
#  'Curb dead end street and trash/still full not emptied.  Make sure to emptied all garbage next week and do not miss him again. Thursday pickup.',
#  'missed the street',
#  'missed- backdoor service',
#  "Trash/Truck is leaving greasy water/juice and stinky on the street, like they compact it in front of her home and it's smells. Clean this up and remove smell. Truck might need to be look into.",
#  'downtown - 3 full carts',
#  'Trash was not picked up on collection day.',
#  'Curb trash/missed cul de sac wants cart emptied. Everyone get was picked.',
#  'missed pick up 2nd time this happen. Curb will wait unit next Friday. Record this.',
#  'missed pick up - picked up all neighbors except her',
#  'Curb trash/miss for Thursday',
#  'cust says backdoor miss two weeks in a row',
#  '1601 mallard creek Ct',
#  'cust says missed trash pickup',
#  "Trash- missed again. I did give customer Red River's info. She is requesting supervisor",
#  'All carts are in the alley- she is having issues every week. Needs route to pick her up on her day.',
#  'cart still out has bags on ground from miss',
#  'missed- entire neighborhood missed.',
#  'cust says missed last 2 weeks; cust requests a call upon arrival',
#  'Missed pick up-',
#  "Hasn't been picked up since December.",
#  'Missed. Overflowing.',
#  'has not had service since january 9th\r\nsaid is making other unauthorized stops in area & not picking up her trash\r\ndid not want to give out name',
#  'Missed pick up at addresses 14885 and 14881 Old Hickory Blvd which are side by side',
#  'Missed- Says she is certain the gate has not been accessed within the last 3 weeks. Wants to make sure that she is picked up tomorrow.',
#  'Repeated trash not picked up on normal day.  Trash has actually NEVER been picked up timely since we moved in.  Repeated phone calls to hub Nashville.',
#  'cart fell in cart',
#  'It appears that the trash was not picked up today on Lock Road. I put my trash out yesterday afternoon and it wasn?t picked up nor was anyone else on the street.',
#  ...]

# %%
trash_df_capitalize = trash_df_read["Description"].str.capitalize()
trash_df_capitalize
# Out:
# 0        House with the wheel chair ramp, they share dr...
# 1                                 Curb/trash miss tuesday.
# 2                                 Curb/trash miss tuesday.
# 3                                                   Missed
# 4                        Missed the even side of the road.
#                                ...
# 20221                            Missed...neighbors missed
# 20222                                         Entire alley
# 20223                                       Missed several
# 20224    Caller stated trash was missed & were only pic...
# 20225                       Possibly others missed as well
# Name: Description, Length: 20226, dtype: object

# %%
# find out total missed pickups based on Description Column
# trash_df_missed_total = trash_df_read[trash_df_read['Description'].str.contains('missed| miss|not pick', case=False, na=True)]
# trash_df_missed_total.info()
# trash_df_missed_total.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12667 entries, 1 to 20225
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    12667 non-null  int64
#  1   Date Opened       12667 non-null  object
#  2   Request           12667 non-null  object
#  3   Description       12636 non-null  object
#  4   Incident Address  12663 non-null  object
#  5   Zip Code          12629 non-null  float64
#  6   Trash Hauler      12116 non-null  object
#  7   Trash Route       12112 non-null  object
#  8   Council District  12639 non-null  float64
#  9   State Plan X      12651 non-null  float64
#  10  State Plan Y      12651 non-null  float64
#  11  LONGITUDE         12651 non-null  float64
#  12  LATITUDE          12651 non-null  float64
# dtypes: float64(6), int64(1), object(6)
# memory usage: 1.4+ MB
#    Request Number Date Opened                               Request  \
# 1           25274   11/1/2017  Trash - Curbside/Alley Missed Pickup
# 2           25276   11/1/2017  Trash - Curbside/Alley Missed Pickup
# 3           25307   11/1/2017  Trash - Curbside/Alley Missed Pickup
# 4           25312   11/1/2017  Trash - Curbside/Alley Missed Pickup
# 7           25327   11/1/2017            Trash Collection Complaint
#
#                                     Description       Incident Address  \
# 1                      Curb/Trash miss Tuesday.  4028 Clarksville Pike
# 2                      Curb/trash miss Tuesday.    6528 Thunderbird Dr
# 3                                        missed   2603 old matthews rd
# 4             Missed the even side of the road.          604 croley dr
# 7  Trash out on time, miss again Tuesday. ALLEY   1816 Jo Johnston Ave
#
#    Zip Code Trash Hauler Trash Route  Council District  State Plan X  \
# 1   37218.0    RED RIVER        4202               1.0   1721259.366
# 2   37209.0    RED RIVER        4205              20.0   1707026.753
# 3   37207.0    WASTE IND        2206               2.0   1735691.771
# 4   37209.0    RED RIVER        4203              20.0   1710185.772
# 7   37203.0        METRO        9208              21.0   1731459.367
#
#    State Plan Y  LONGITUDE   LATITUDE
# 1   685444.7996 -86.838103  36.213470
# 2   659887.4716 -86.885562  36.142923
# 3   685027.2459 -86.789170  36.212652
# 4   664205.1011 -86.874995  36.154861
# 7   666013.6012 -86.802988  36.160330

# %%
# find out total missed pickups based on Request Column
trash_df_missed_total = trash_df_read[trash_df_read["Request"]!= "Damage to Property"]
trash_df_missed_total.info()
trash_df_missed_total.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19969 entries, 0 to 20225
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    19969 non-null  int64
#  1   Date Opened       19969 non-null  object
#  2   Request           19969 non-null  object
#  3   Description       19938 non-null  object
#  4   Incident Address  19960 non-null  object
#  5   Zip Code          19897 non-null  float64
#  6   Trash Hauler      19079 non-null  object
#  7   Trash Route       19045 non-null  object
#  8   Council District  19921 non-null  float64
#  9   State Plan X      19942 non-null  float64
#  10  State Plan Y      19942 non-null  float64
#  11  LONGITUDE         19942 non-null  float64
#  12  LATITUDE          19942 non-null  float64
# dtypes: float64(6), int64(1), object(6)
# memory usage: 2.1+ MB
#    Request Number Date Opened                               Request  \
# 0           25270   11/1/2017                      Trash - Backdoor
# 1           25274   11/1/2017  Trash - Curbside/Alley Missed Pickup
# 2           25276   11/1/2017  Trash - Curbside/Alley Missed Pickup
# 3           25307   11/1/2017  Trash - Curbside/Alley Missed Pickup
# 4           25312   11/1/2017  Trash - Curbside/Alley Missed Pickup
#
#                                          Description       Incident Address  \
# 0  house with the wheel chair ramp, they share dr...         3817 Crouch Dr
# 1                           Curb/Trash miss Tuesday.  4028 Clarksville Pike
# 2                           Curb/trash miss Tuesday.    6528 Thunderbird Dr
# 3                                             missed   2603 old matthews rd
# 4                  Missed the even side of the road.          604 croley dr
#
#    Zip Code Trash Hauler Trash Route  Council District  State Plan X  \
# 0   37207.0    RED RIVER        3205               2.0   1727970.412
# 1   37218.0    RED RIVER        4202               1.0   1721259.366
# 2   37209.0    RED RIVER        4205              20.0   1707026.753
# 3   37207.0    WASTE IND        2206               2.0   1735691.771
# 4   37209.0    RED RIVER        4203              20.0   1710185.772
#
#    State Plan Y  LONGITUDE   LATITUDE
# 0   686779.4781 -86.815392  36.217292
# 1   685444.7996 -86.838103  36.213470
# 2   659887.4716 -86.885562  36.142923
# 3   685027.2459 -86.789170  36.212652
# 4   664205.1011 -86.874995  36.154861

# %%
# find out total missed pickups based on Request Column
trash_df_missed_total_per_request_count = trash_df_missed_total["Request"].value_counts()
trash_df_missed_total_per_request_count
# Out:
# Request
# Trash - Curbside/Alley Missed Pickup    15028
# Trash - Backdoor                         2629
# Trash Collection Complaint               2312
# Name: count, dtype: int64

# %%
# Filter missed for RED RIVER
trash_df_missed_red_river = trash_df_missed_total[trash_df_missed_total["Trash Hauler"]=="RED RIVER"]
trash_df_missed_red_river

# Filter missed count for RED RIVER
trash_df_missed_red_river_count = trash_df_missed_red_river["Request"].value_counts()
trash_df_missed_red_river_count
# Out:
# Request
# Trash - Curbside/Alley Missed Pickup    10715
# Trash - Backdoor                         2196
# Trash Collection Complaint               1287
# Name: count, dtype: int64

# %%
trash_df_missed_red_river_count["missed_count"] = trash_df_missed_red_river[trash_df_missed_red_river["Incident Address"]].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 trash_df_missed_red_river_count["missed_count"] = trash_df_missed_red_river[trash_df_missed_red_river["Incident Address"]].value_counts()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([                                            '3817 Crouch Dr',\n                                            '4028 Clarksville Pike',\n                                              '6528 Thunderbird Dr',\n                                                    '604 croley dr',\n                                                   '3602 floral dr',\n                                    '4484 Lavergne Couchville Pike',\n                                              '3113 HYDES FERRY RD',\n                                           '3210 Whites Creek Pike',\n                                              '6543 Thunderbird Dr',\n                                            '2218 BUENA VISTA PIKE',\n       ...\n             '3929 Stewarts Ln, Nashville, TN 37218, United States',\n              '639 Heritage Dr, Nashville, TN 37115, United States',\n                    '105 Lake Side Ct, Nashville, Tennessee, 37217',\n             '3318 Anderson Rd, Nashville, TN 37013, United States',\n                                                   '3105 fisher dr',\n            '2709 Crestdale Dr, Nashville, TN 37214, United States',\n                                           '2731 Murfreesboro Pike',\n           '2943 Windemere Cir, Nashville, TN 37214, United States',\n       '3325 Murfreesboro Pike, Nashville, TN 37013, United States',\n              '604 Somerset Ct, Nashville, TN 37217, United States'],\n      dtype='object', length=14198)] are in the [columns]"

# %%
# Missed Trash Pickups

# In this data question you will be working data of service request related to missed trash pickups from hubNashville, Metro Nashville government's 
# comprehensive customer service system (https://hub.nashville.gov).

# As part of Metro's contract with Red River Waste Solutions, failure to remedy an action or inaction will result in liquidated damages. One category 
# of liquidated damages is related to chronic problems in any category of service at the same premises. A chronic problem is defined as more than one 
# missed pickup for any address. The first missed pickup will not result in a fine; however, every subsequent missed pickup will result in a $200 fine.

# Your job is to determine the total amount of damages due to missed pickups. Note that not all rows that you have been provided correspond to missed
# pickups and that you will need to ensure that you are only counting missed pickups.

# After determining the total amount of damages, you can look at other questions:
# ⦁	What other types of complaints are there?
# ⦁	Are there any geospatial analysis you can do?  Which visualizations can you create?
# ⦁	How do metro crews compare to the contractor's performance?
# ⦁	How much does each trash hauler owe?
# ⦁	What were to total missed pickup by route?
